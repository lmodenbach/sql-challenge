# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import psycopg2 as pg
import pandas.io.sql as psql

# %%
# get connected to the database
conn = pg.connect("host=localhost dbname=EmployeeCSV_DB user=postgres password=password port=5432")

# %%
titles_df = psql.read_sql("SELECT * FROM titles", conn)
titles_df.head()
# Out:
#   title_id              titles
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
employees_df = psql.read_sql("SELECT * FROM employees", conn)
employees_df.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053        e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444        e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786        s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238        e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18

# %%
departments_df = psql.read_sql("SELECT * FROM departments", conn)
departments_df.head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development

# %%
dept_managers_df = psql.read_sql("SELECT * FROM dept_managers", conn)
dept_managers_df.head()
# Out:
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183

# %%
dept_emp_df = psql.read_sql("SELECT * FROM dept_emp", conn)
dept_emp_df.head()
# Out:
#    emp_no dept_no
# 0   10001    d005
# 1   10002    d007
# 2   10003    d004
# 3   10004    d004
# 4   10005    d003

# %%
salaries_df = psql.read_sql("SELECT * FROM salaries", conn)
salaries_df.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
#Create a histogram to visualize the most common salary ranges for employees

# %%
print(salaries_df['salary'].max())
print(salaries_df['salary'].min())
# Out:
# 129492
# 40000

# %%
bins = [39999, 49999, 59999, 69999, 79999, 89999, 99999, 109999, 119999, 130000]
labels = ['40K-49K', '50K-59K', '60K-69K', '70K-79K', '80K-89K', '90K-99K', '100K-109K', '110K-119K', '120K-130K']

# %%
#a bar chart that functions as a histogram, but is prettier and more customizable

salaries_df['Salary Range'] = pd.cut(salaries_df['salary'], bins, labels=labels)
salaries_counts = salaries_df['Salary Range'].value_counts()
bar_chart = salaries_counts.plot.bar(color=['red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue'] , title='Frequency of Salary Range', xlabel='Salary Range in $', ylabel='Number of Employees in Range', rot=45)

# %%
#a proper histogram

fig, ax = plt.subplots()

ind = np.array(bins[:-1])
width = np.array([bins[i+1]-bins[i] for i in range(len(bins)-1)])

ax.hist(salaries_df['salary'], bins=bins)
ax.set_xticks(ind + width/2)
ax.set_xticklabels((labels), rotation=45) 
plt.xlabel('Salary Range in $')
plt.ylabel('Frequency')
plt.title('Frequency of Salary Range')
plt.show()

# %%
#Create a bar chart of average salary by title

# %%
employee_salary_df = employees_df.merge(salaries_df, on=['emp_no'], how='inner')
employee_salary_df.rename(columns={'emp_title_id':'title_id'}, inplace=True)
employee_salary_title_df = employee_salary_df.merge(titles_df, on=['title_id'], how='inner')
employee_salary_title_df.head(10)
# Out:
#    emp_no title_id  birth_date  first_name   last_name sex   hire_date  \
# 0  473302    s0001  1953-07-25    Hideyuki    Zallocco   M  1990-04-28
# 1  421786    s0001  1957-09-28       Xiong    Verhoeff   M  1987-11-26
# 2  273487    s0001  1957-04-14   Christoph     Parfitt   M  1991-06-28
# 3  246449    s0001  1958-03-23       Subbu  Bultermann   F  1988-03-25
# 4   48085    s0001  1964-01-19  Venkatesan        Gilg   M  1993-06-28
# 5  476443    s0001  1952-08-27        Ziya      Asmuth   M  1995-08-24
# 6  424270    s0001  1963-01-15      Kellyn   Yoshizawa   F  1995-05-08
# 7  427958    s0001  1957-05-03    Feixiong      Poujol   F  1985-05-11
# 8  280408    s0001  1964-09-19     Elliott        Perl   M  1987-10-29
# 9  229010    s0001  1961-11-12        Mark    Cappelli   M  1990-05-07
#
#    salary Salary Range titles
# 0   40000      40K-49K  Staff
# 1   40000      40K-49K  Staff
# 2   56087      50K-59K  Staff
# 3   87084      80K-89K  Staff
# 4   63016      60K-69K  Staff
# 5   63371      60K-69K  Staff
# 6   60678      60K-69K  Staff
# 7   63377      60K-69K  Staff
# 8   75963      70K-79K  Staff
# 9   40000      40K-49K  Staff

# %%
#mean of salary by title: study_data_capomulin.groupby(['Mouse ID'])['Weight (g)'].mean()


e
